# %% [markdown]
# 类对象

# %%
class MyClass:
    """A simple example class"""
    i = 12345
    def f(self):
        return 'hello world'

# %%
MyClass.i
# Out:
# 12345

# %%
MyClass.f
# Out:
# <function __main__.MyClass.f>

# %%
MyClass.__doc__
# Out:
# 'A simple example class'

# %% [markdown]
# 初始状态

# %%
class MyClass:
    """A simple example class"""
    
    def __init__(self):
        self.data = []
    
    i = 12345
    def f(self):
        return 'hello world'
