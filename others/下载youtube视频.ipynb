# %%
#youtube_url = "https://www.youtube.com/watch?v=iALfvFpcItE"

# %%
from pytube import YouTube
yt = YouTube(youtube_url)
yt = yt.get('mp4', '720p')
yt.download('youtube')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Users\J\AppData\Local\Continuum\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\Users\J\AppData\Local\Continuum\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\Users\J\AppData\Local\Continuum\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# ...

# %%
urls = ['https://www.youtube.com/watch?v=kzt3-FHdAeM&list=PLfYUBJiXbdtS2UQRzyrxmyVHoGW0gmLSM',
       'https://www.youtube.com/watch?v=8rjRfW4JM2I&list=PLfYUBJiXbdtS2UQRzyrxmyVHoGW0gmLSM&index=2',
       'https://www.youtube.com/watch?v=Th_ckFbc6bI&list=PLfYUBJiXbdtS2UQRzyrxmyVHoGW0gmLSM&index=3',
       'https://www.youtube.com/watch?v=e3aM6XTekJc&list=PLfYUBJiXbdtS2UQRzyrxmyVHoGW0gmLSM&index=4',
        'https://www.youtube.com/watch?v=6kwQEBMandw&list=PLfYUBJiXbdtS2UQRzyrxmyVHoGW0gmLSM&index=5',
       'https://www.youtube.com/watch?v=V2h3IOBDvrA&list=PLfYUBJiXbdtS2UQRzyrxmyVHoGW0gmLSM&index=6',
       'https://www.youtube.com/watch?v=qvRL74L81lg&list=PLfYUBJiXbdtS2UQRzyrxmyVHoGW0gmLSM&index=7',
       'https://www.youtube.com/watch?v=ll9y1U0SoVY&list=PLfYUBJiXbdtS2UQRzyrxmyVHoGW0gmLSM&index=8',
       ]

# %%
for url in urls:
    yt = YouTube(youtube_url)
    yt = yt.get('mp4', '720p')
    yt.download('fastai'+url[-1])
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Users\J\AppData\Local\Continuum\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\Users\J\AppData\Local\Continuum\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\Users\J\AppData\Local\Continuum\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# ...
