# %%
import itchat
# Out:
# █

# %%
## 登录
itchat.login()
# Out:
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as -与世无忧

# %% [markdown]
# # 1. 微信好友男女比例

# %%
# 获取好友列表
friends = itchat.get_friends(update=True)[0:]

# %%
# 初始化计数器，有男有女，当然，有些人是不填的
male = female = other = 0

# 遍历这个列表，列表里第一位是自己，所以从"自己"之后开始计算
# 1表示男性，2女性
for i in friends[1:]:
    sex = i["Sex"]
    if sex == 1:
        male += 1
    elif sex == 2:
        female += 1
    else:
        other += 1

# %%
total = len(friends[1:])

# %%
print("男性好友：%.2f%%" % (float(male) / total * 100))
print("女性好友：%.2f%%" % (float(female) / total * 100))
print("其他：%.2f%%" % (float(other) / total * 100))
# Out:
# 男性好友：31.15%
# 女性好友：51.64%
# 其他：17.21%

# %%
plt.pie([male, female, other], explode=[0.05,0.05,0.05], labels=['男性','女性','未填写'], autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal');

# %%
from echarts import Echart, Legend, Pie

chart = Echart(u'%s的微信好友性别比例' % (friends[0]['NickName']), 'from WeChat')
chart.use(Pie('WeChat',
              [{'value': male, 'name': u'男性 %.2f%%' % (float(male) / total * 100)},
               {'value': female, 'name': u'女性 %.2f%%' % (float(female) / total * 100)},
               {'value': other, 'name': u'其他 %.2f%%' % (float(other) / total * 100)}],
              radius=["50%", "70%"]))
chart.use(Legend(["male", "female", "other"]))
del chart.json["xAxis"]
del chart.json["yAxis"]
chart.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-0eb81099fbe6> in <module>()
# ----> 1 from echarts import Echart, Legend, Pie
#       2
#       3 chart = Echart(u'%s的微信好友性别比例' % (friends[0]['NickName']), 'from WeChat')
#       4 chart.use(Pie('WeChat',
#       5               [{'value': male, 'name': u'男性 %.2f%%' % (float(male) / total * 100)},
#
# ModuleNotFoundError: No module named 'echarts'

# %% [markdown]
# # 2. 好友个性签名词云
