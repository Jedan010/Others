# %%
from pymongo import  MongoClient

# %%
client = MongoClient()

# %%
db = client['test_database']

# %%
client.database_names()
# Out:
# ['admin', 'lianjia', 'local', 'stackdata', 'taobao', '链家']

# %%
db = client['stackdata']

# %%
db.collection_names()
# Out:
# ['tickdata']

# %%
post = db.tickdata

# %%
post.count()
# Out:
# 1781

# %%
datas = []
for data in posts.find():
    datas.append(data)

# %%
datas = pd.DataFrame(datas)
datas.set_index('链家编号', inplace=True)

# %%
db = client['链家']

# %%
db.collection_names()
# Out:
# ['二手2', '二手']

# %%
posts = db['二手2']

# %%
for i in post.find({'price': 10.96}):
    print(i)
# Out:
# {'_id': ObjectId('590da904dcbb4417544305c9'), 'time': '14:59:58', 'price': 10.96, 'change': '--', 'volume': 2, 'amount': 2192, 'type': '买盘'}
# {'_id': ObjectId('590da904dcbb4417544305ca'), 'time': '14:59:53', 'price': 10.96, 'change': '--', 'volume': 2, 'amount': 2192, 'type': '买盘'}
# {'_id': ObjectId('590da904dcbb4417544305cb'), 'time': '14:59:43', 'price': 10.96, 'change': '--', 'volume': 13, 'amount': 14248, 'type': '买盘'}
# {'_id': ObjectId('590da904dcbb4417544305cc'), 'time': '14:59:43', 'price': 10.96, 'change': '--', 'volume': 7, 'amount': 7672, 'type': '买盘'}
# {'_id': ObjectId('590da904dcbb4417544305cd'), 'time': '14:59:33', 'price': 10.96, 'change': '--', 'volume': 2, 'amount': 2192, 'type': '买盘'}
# {'_id': ObjectId('590da904dcbb4417544305ce'), 'time': '14:59:28', 'price': 10.96, 'change': '--', 'volume': 12, 'amount': 13152, 'type': '买盘'}
# ...

# %%
posts.f
